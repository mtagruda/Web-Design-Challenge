# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
cities_one = "/Users/melissaagruda/Desktop/Homework/webdesign/cities.csv"

# %%
cities_one_df = pd.read_csv(cities_one, encoding="ISO-8859-1")

# %%
cities_one_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      yulara          90      CK  1567633128        57 -21.21 -159.78
# 1        vila           0      RU  1567633128        68  51.20   49.73
# 2      luanda          75      ET  1567633128        87   8.96   38.73
# 3  kaitangata           0      FR  1567633128        76  45.06    5.82
# 4  kralendijk          20      US  1567632926        54  42.65  -73.75
#
#    Max Temp  Wind Speed
# 0     77.00       19.46
# 1     53.51        5.70
# 2     60.80        2.24
# 3     71.01        5.82
# 4     81.00       17.22

# %%
cities_one_df["Humidity"].head()
# Out:
# 0    57
# 1    68
# 2    87
# 3    76
# 4    54
# Name: Humidity, dtype: int64

# %%
print(cities_one_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>yulara</td>
#       <td>90</td>
#       <td>CK</td>
#       <td>1567633128</td>
#       <td>57</td>
#       <td>-21.21</td>
#       <td>-159.78</td>
#       <td>77.00</td>
#       <td>19.46</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>vila</td>
#       <td>0</td>
#       <td>RU</td>
#       <td>1567633128</td>
#       <td>68</td>
#       <td>51.20</td>
#       <td>49.73</td>
#       <td>53.51</td>
#       <td>5.70</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>luanda</td>
#       <td>75</td>
#       <td>ET</td>
#       <td>1567633128</td>
#       <td>87</td>
# ...
